# %%
#Question1. Write a function that stutters a word as if someone is struggling to read it. The first two letters are repeated twice with an ellipsis ... and space after each, and then the word is pronounced with a question mark ?.

def read(string):
    return (string[:2]+'... '+string[:2]+'... '+string+"?")

# %%
read('incrediable')
# Out:
# 'in... in... incrediable?'

# %%
#Question 2.Create a function that takes an angle in radians and returns the corresponding angle in degrees rounded to one decimal place.

def radian_to_degree(n):
    return round(n*57.2957795,1)

# %%
radian_to_degree(20)
# Out:
# 1145.9

# %%
#Question 3. In this challenge, establish if a given integer num is a Curzon number.

def curson(n):
    a=2**(n)+1
    b=2*(n)+1
    if a%b==0:
        return True
    else:
        return False

# %%
curson(5)
# Out:
# True

# %%
#Question 4.Given the side length x find the area of a hexagon.

def area(n):
    return round((3*(pow(3,1/2)*(n*n)))/2,1)

# %%
area(2)
# Out:
# 10.4

# %%
#Question 5. Create a function that returns a base-2 (binary) representation of a base-10 (decimal) string number.

def binary(n):
    return bin(n).replace("0b", "")

# %%
binary(10)
# Out:
# '1010'
