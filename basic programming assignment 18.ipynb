# %%
#Question 1 Create a function that takes a list of non-negative integers and strings and return a new list without the strings.

def filter_list(lst):
    lst1=[]
    for i in lst:
        if type(i)==int:
            lst1.append(i)
    return lst1

# %%
filter_list([1,2,'a','b'])
# Out:
# [1, 2]

# %%
#Question 2 The Reverse takes a string as input and returns that string in reverse order, with the opposite case.

def reverse(string):
    string=string.swapcase()
    return ''.join(reversed(string))

# %%
reverse('Hello World')
# Out:
# 'DLROw OLLEh'

# %%
#Question 3.Your task is to unpack the list writeyourcodehere into three variables, being first, middle, and last, with middle being everything in between the first and last element. Then print all three variables.

def func(lst):
    first=lst[0]
    middle=lst[1:-1]
    last=lst[-1]
    print('The first element is',first)
    print('The middle elements are',middle)
    print('The last element is',last)

# %%
func([1,2,3,4,56,52,45])
# Out:
# The first element is 1
# The middle elements are [2, 3, 4, 56, 52]
# The last element is 45

# %%
#Question 4 Write a function that calculates the factorial of a number recursively.

def fact(n):
    if n==1:
        return 1
    else:
        return n*fact(n-1)

# %%
fact(5)
# Out:
# 120

# %%
#Question 5 Write a function that moves all elements of one type to the end of the list.

def move_to_end(lst,num):
    for i in lst:
        if i==num:
            lst.append(i)
            lst.remove(i)
    return lst

# %%
move_to_end([1,1,2,3,3,4,5],1)
# Out:
# [2, 3, 3, 4, 5, 1, 1]
