# %%
#1. Write a Python Program to Display Fibonacci Sequence Using Recursion?
def fibonacci(x):
    if x==0:
        return 0
    elif x==1:
        return 1
    else:
        return(fibonacci(x-1)+fibonacci(x-2))
for i in range(int(input('Fibonacci Sequence till---->'))):
    print(fibonacci(i))
# Out:
# Fibonacci Sequence till---->6
# 0
# 1
# 1
# 2
# 3
# 5

# %%
#2. Write a Python Program to Find Factorial of Number Using Recursion?
def fact(a):
    if a==1:
        return 1
    return a*fact(a-1)

# %%
# 3. Write a Python Program to calculate your Body Mass Index?
weight=float(input('enter weight in kg---->'))
height=float(input('enter weight in meters--->'))
print('BMI = ',(weight/(pow(height,2))))
# Out:
# enter weight in kg---->80
# enter weight in meters--->1.79
# BMI =  24.968009737523797

# %%
#4. Write a Python Program to calculate the natural logarithm of any number?
import math
a=float(input('enter the number'))
print(math.log(a)/math.log(2.71828))
# Out:
# enter the number5
# 1.6094389950276147

# %%
# 5. Write a Python Program for cube sum of first n natural numbers?
a=int(input('sum of first n natural numbers required'))
sum1=0
for i in range(a+1):
    sum1=sum1+pow(i,3)
print(sum1)
# Out:
# sum of first n natural numbers required5
# 225
